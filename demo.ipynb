# %%
import pygraphite

# %%
# !pip install networkx matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 KB 1.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import networkx
import numpy as np

# %%
G = networkx.DiGraph()

for i in range(5):
    G.add_node(i, features=np.random.rand(4))


G.add_edges_from([(0, 1), (1, 2), (2, 3), (3, 4), (4, 0)])





import matplotlib.pyplot as plt

networkx.draw(G, with_labels=True)
plt.show()

# %%
"""
- proof of sus - wash trading or how far away from sus address
- Best execution
- social 
- pagerank 
"""

X = {'A': (1, 0), 'B': (0, 1), 'C': (0, 1), 'D': (0, 1)}

# What is the proof
params = {}
suc_proof, pagerank_values = pygraphite.pagerank(G,X, params)
"""
Under the hood:
1) (Python) Loads the algorithm from src/algorithms
2) (Python) Prepare the data, then make API call to Noir proof generator
3) (Noir) Generate the proof with the prepared 
"""



"""
Example of pagerank_values:
{"A": 0.2, "B": 0.1, "C": 0.4, "D": 0.3}
"""
